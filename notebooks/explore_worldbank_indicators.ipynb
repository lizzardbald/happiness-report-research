# %% [markdown]
# # Browse World Bank indicators with `wbgapi`
#
# Scratch notebook for picking the indicator codes consumed by `src/data/worldbank.py` and sanity-checking coverage for 2015–2019.

# %%
# import wbgapi as wb
# import pandas as pd

# %% [markdown]
# ## Find candidate indicators

# %%
# wb.series.info(q='gdp per capita')
# wb.series.info(q='unemployment')

# %% [markdown]
# ## Pull a window and inspect coverage

# %%
# df = wb.data.DataFrame('NY.GDP.PCAP.PP.CD', time=range(2015, 2020), labels=True)
# df.head()
