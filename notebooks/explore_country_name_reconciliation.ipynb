# %% [markdown]
# # Country-name reconciliation across sources
#
# Scratch notebook used to identify name mismatches between the happiness CSVs, World Bank, and REST Countries, and to feed the override dictionary in `src/data/reconcile.py`.

# %%
# import pandas as pd
# import country_converter as coco

# %% [markdown]
# ## Find names country_converter cannot resolve

# %%
# from src.data import happiness
# names = happiness.load_all()['country'].unique()
# resolved = coco.convert(names=names, to='ISO3', not_found=None)
# unresolved = [n for n, code in zip(names, resolved) if code is None]
# unresolved
