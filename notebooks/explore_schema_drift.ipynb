# %% [markdown]
# # Schema drift across the 2015–2019 happiness CSVs
#
# Scratch notebook used to inspect the per-year column lists, derive the canonical schema, and validate `src/data/happiness.py::load_all`.

# %%
# import pandas as pd
# from pathlib import Path

# %% [markdown]
# ## Compare raw column sets per year

# %%
# raw_dir = Path('../data/raw/world-happines-2015-2019')
# for csv in sorted(raw_dir.glob('*.csv')):
#     cols = list(pd.read_csv(csv, nrows=0).columns)
#     print(csv.name, cols)
